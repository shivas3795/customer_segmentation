# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier 
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn import metrics
from sklearn.cluster import KMeans, AgglomerativeClustering, DBSCAN
from sklearn.mixture import GaussianMixture
from sklearn.metrics import silhouette_samples, silhouette_score

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('Customer Data.csv')
df.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %% [markdown]
# ### EDA

# %%
df.shape
# Out:
# (8950, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
# ...

# %%
df.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# ...

# %%
# sum of null values
df.isnull().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
#  filling null values with mean
df['MINIMUM_PAYMENTS'] = df['MINIMUM_PAYMENTS'].fillna(df['MINIMUM_PAYMENTS'].mean())
df['CREDIT_LIMIT'] = df['CREDIT_LIMIT'].fillna(df['CREDIT_LIMIT'].mean())

# %%
df.isnull().sum()
# Out:
# CUST_ID                             0
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %%
# checking duplicate rows
df.duplicated().sum()
# Out:
# 0

# %%
# dropping Customer ID 
df.drop('CUST_ID',axis=1,inplace=True)

# %%
# kde (kernel density estimation) plot for each column for getting distribution
plt.figure(figsize=(35,50))
for i,col in enumerate(df.columns):
    if df[col].dtype != 'object':
        ax = plt.subplot(9,2,i+1)
        sns.kdeplot(df[col], ax=ax)
        plt.xlabel(col)
        
plt.show()

# %%
# distplot for each column (histogram + kde), 'bw':bandwidth for plot, 'lw':linewidth
plt.figure(figsize=(10,60))
for i in range(len(df.columns)):
    plt.subplot(17,1,i+1)
    sns.distplot(df[df.columns[i]], kde_kws={'color':'b','bw':0.1,'lw':2,'label':'KDE'},hist_kws={'color':'g'})
    plt.title(df.columns[i])
        
plt.tight_layout() 
# The tight_layout() function in pyplot module of matplotlib library is used to automatically adjust subplot parameters 
# to give specified padding

# %%
# correlation heatmap
plt.figure(figsize=(12,12))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
# scaling dataframe
scalar = StandardScaler()
scaled_df = scalar.fit_transform(df)

# %%
# dimensionality reduction using PCA
from sklearn.decomposition import PCA

# converting data into 2D dataframe for visualization
pca = PCA(n_components=2)
principal_components = pca.fit_transform(scaled_df)
pca_df = pd.DataFrame(data=principal_components, columns=['PCA1','PCA2'])
pca_df
# Out:
#           PCA1      PCA2
# 0    -1.682222 -1.076482
# 1    -1.138289  2.506577
# 2     0.969692 -0.383251
# 3    -0.873629  0.043101
# 4    -1.599437 -0.688624
# ...        ...       ...
# 8945 -0.359637 -2.016281
# 8946 -0.564373 -1.639231
# 8947 -0.926211 -1.810914
# 8948 -2.336557 -0.658116
# 8949 -0.556413 -0.400296
#
# [8950 rows x 2 columns]

# %%
pd.DataFrame(scaled_df).head()
# Out:
#          0         1         2         3         4         5         6   \
# 0 -0.731989 -0.249434 -0.424900 -0.356934 -0.349079 -0.466786 -0.806490
# 1  0.786961  0.134325 -0.469552 -0.356934 -0.454576  2.605605 -1.221758
# 2  0.447135  0.518084 -0.107668  0.108889 -0.454576 -0.466786  1.269843
# 3  0.049099 -1.016953  0.232058  0.546189 -0.454576 -0.368653 -1.014125
# 4 -0.358775  0.518084 -0.462063 -0.347294 -0.454576 -0.466786 -1.014125
#
#          7         8         9         10        11        12        13  \
# 0 -0.678661 -0.707313 -0.675349 -0.476070 -0.511333 -0.960433 -0.528979
# 1 -0.678661 -0.916995  0.573963  0.110074 -0.591796  0.688639  0.818642
# 2  2.673451 -0.916995 -0.675349 -0.476070 -0.109020  0.826062 -0.383805
# 3 -0.399319 -0.916995 -0.258913 -0.329534 -0.551565  0.826062 -0.598688
# 4 -0.399319 -0.916995 -0.675349 -0.476070 -0.551565 -0.905464 -0.364368
#
#          14        15       16
# 0 -0.310968 -0.525551  0.36068
# 1  0.089310  0.234227  0.36068
# ...

# %% [markdown]
# ### Model preparation

# %%
# finding k by elbow method
inertia = []
k_range = range(1,15)
for i in k_range:
    kmeans = KMeans(n_clusters = i)
    kmeans.fit_predict(pd.DataFrame(scaled_df))
    inertia.append(kmeans.inertia_)
plt.plot(k_range,inertia,'bx-') # 'bx-' to show points
plt.xlabel('K value')
plt.ylabel('Inertia')
plt.title('Value of K using elbow method')
plt.show()

# %% [markdown]
# At k=4, graph is forming elbow

# %%
# model building using KMeans
kmeans_model = KMeans(4)
kmeans_model.fit_predict(scaled_df) #predicting clusters

# concatinating cluster and pca output
pca_df_kmeans = pd.concat([pca_df,pd.DataFrame({'cluster':kmeans_model.labels_})],axis=1)

# %%
# visualizing clustered dataframe
plt.figure(figsize=(8,8))
ax = sns.scatterplot(x='PCA1',y='PCA2',hue='cluster',data=pca_df_kmeans, palette=['red','green','blue','black'])
plt.title('clustering using K-Means algorithm')
plt.show()

# %%
# finding all cluster centers
transform_data = pd.DataFrame(data = kmeans_model.cluster_centers_,columns=[df.columns])
transform_data
# Out:
#     BALANCE BALANCE_FREQUENCY PURCHASES ONEOFF_PURCHASES  \
# 0  0.954485          0.462694  3.125845         2.713251
# 1 -0.321688          0.242574  0.109044         0.000926
# 2 -0.265552         -0.368944 -0.343190        -0.230500
# 3  1.459578          0.384753 -0.234638        -0.163914
#
#   INSTALLMENTS_PURCHASES CASH_ADVANCE PURCHASES_FREQUENCY  \
# 0               2.406470    -0.155091            1.136338
# 1               0.255904    -0.366373            0.983721
# 2              -0.387798    -0.182691           -0.797823
# 3              -0.253747     1.688972           -0.504848
#
#   ONEOFF_PURCHASES_FREQUENCY PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                   1.798653                         1.065918
# 1                   0.317153                         0.874138
# 2                  -0.389437                        -0.714246
# 3                  -0.212939                        -0.450201
#
# ...

# %%
# inverse transform the data (transformed data using scaling will convert to original)
cluster_centers = scalar.inverse_transform(transform_data)
cluster_centers = pd.DataFrame(data = cluster_centers,columns=[df.columns])
cluster_centers
# Out:
#        BALANCE BALANCE_FREQUENCY    PURCHASES ONEOFF_PURCHASES  \
# 0  3551.153761          0.986879  7681.620098      5095.878826
# 1   894.907458          0.934734  1236.178934       593.974874
# 2  1011.751528          0.789871   269.973466       209.853863
# 3  4602.462714          0.968415   501.896219       320.373681
#
#   INSTALLMENTS_PURCHASES CASH_ADVANCE PURCHASES_FREQUENCY  \
# 0            2587.208264   653.638891            0.946418
# 1             642.478274   210.570626            0.885165
# 2              60.386625   595.759339            0.170146
# 3             181.607404  4520.724309            0.287731
#
#   ONEOFF_PURCHASES_FREQUENCY PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                   0.739031                         0.788060
# 1                   0.297070                         0.711842
# 2                   0.086281                         0.080578
# 3                   0.138934                         0.185516
#
# ...

# %%
# concatenating clusters with each rows
cluster_df = pd.concat([df,pd.DataFrame({'Cluster': kmeans_model.labels_})],axis=1)
cluster_df.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 3  1666.670542           0.636364    1499.00           1499.00
# 4   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# ...

# %%
cluster_1_df = cluster_df[cluster_df['Cluster']==0]
cluster_1_df.head(3)
# Out:
#         BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 6    627.260806                1.0    7091.01           6402.63
# 21  6369.531318                1.0    6359.95           5910.04
# 57  2386.330629                1.0    5217.62           4789.09
#
#     INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 6                   688.38      0.000000             1.000000
# 21                  449.91    229.028245             1.000000
# 57                  428.53      0.000000             0.916667
#
#     ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 6                     1.000000                               1.0
# 21                    0.916667                               1.0
# 57                    0.916667                               0.5
#
#     CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 6                 0.000000                 0             64       13500.0
# ...

# %%
cluster_2_df = cluster_df[cluster_df['Cluster']==1]
cluster_2_df.head(3)
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 2  2495.148862                1.0     773.17            773.17
# 5  1809.828751                1.0    1333.28              0.00
# 7  1823.652743                1.0     436.20              0.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 2                    0.00           0.0             1.000000
# 5                 1333.28           0.0             0.666667
# 7                  436.20           0.0             1.000000
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 2                         1.0                          0.000000
# 5                         0.0                          0.583333
# 7                         0.0                          1.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 2                     0.0                 0             12        7500.0
# ...

# %%
cluster_3_df = cluster_df[cluster_df['Cluster']==2]
cluster_3_df.head(3)
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182       95.4               0.0
# 3  1666.670542           0.636364     1499.0            1499.0
# 4   817.714335           1.000000       16.0              16.0
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 3                    0.083333                          0.000000
# 4                    0.083333                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                0.000000                 0              2        1000.0
# ...

# %%
cluster_4_df = cluster_df[cluster_df['Cluster']==3]
cluster_4_df.head(3)
# Out:
#         BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 1   3202.467416           0.909091       0.00              0.00
# 15  6886.213231           1.000000    1611.70              0.00
# 23  3800.151377           0.818182    4248.35           3454.56
#
#     INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 1                     0.00   6442.945483                  0.0
# 15                 1611.70   2301.491267                  0.5
# 23                  793.79   7974.415626                  1.0
#
#     ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 1                     0.000000                          0.000000
# 15                    0.000000                          0.500000
# 23                    0.083333                          0.916667
#
#     CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 1                 0.250000                 4              0        7000.0
# ...

# %%
# distribution count of each cluster
sns.countplot(x = 'Cluster',data = cluster_df)
# Out:
# <AxesSubplot:xlabel='Cluster', ylabel='count'>

# %%
# plotting each column vs each cluster
for c in cluster_df.drop('Cluster',axis=1):
    grid = sns.FacetGrid(cluster_df,col='Cluster')
    grid = grid.map(plt.hist, c)
    
plt.show()

# %%
# saving model
import joblib
joblib.dump(kmeans_model, 'kmeans_model.pkl')
# Out:
# ['kmeans_model.pkl']

# %%
# saving final clustered file
cluster_df.to_csv('clustered_customer_data.csv')

# %% [markdown]
# ### Making model for clustering customers using decision tree

# %%
# splitting datasets
x = cluster_df.drop('Cluster',axis=1)
y = cluster_df['Cluster']
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25)

# %%
x_train.shape
# Out:
# (6712, 17)

# %%
x_test.shape
# Out:
# (2238, 17)

# %%
# Decision Tree
model = DecisionTreeClassifier(criterion='entropy')
model.fit(x_train,y_train)
y_pred = model.predict(x_test)

# %%
model.score(x_test,y_test)
# Out:
# 0.9410187667560321

# %%
# classification report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.96      0.92       100
#            1       0.96      0.94      0.95       841
#            2       0.94      0.96      0.95      1014
#            3       0.91      0.88      0.89       283
#
#     accuracy                           0.94      2238
#    macro avg       0.92      0.93      0.93      2238
# weighted avg       0.94      0.94      0.94      2238

# %%
# confusion matrix
print(metrics.confusion_matrix(y_test,y_pred))
# Out:
# [[ 96   3   1   0]
#  [  9 791  32   9]
#  [  2  26 970  16]
#  [  1   8  25 249]]

# %%
# heatmap of confusion matrix
cm = metrics.confusion_matrix(y_test,y_pred)
plt.figure(figsize=(8,5))
sns.heatmap(cm,annot=True,fmt='g') #fmt='g' removes scientific annotation
plt.xlabel('Predicted')
plt.ylabel("Truth")
# Out:
# Text(51.0, 0.5, 'Truth')

# %%
# save decision tree model
import pickle
file = 'final_model.sav'
pickle.dump(model, open(file,'wb'))
